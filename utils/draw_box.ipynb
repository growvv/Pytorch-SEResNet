# %%
import numpy as np
import matplotlib.pyplot as plt

img_dir = 'draw/res4'

def draw_box(img):
    # 画图
    plt.figure(figsize=(10, 10))
    # plt.imshow(img)
    plt.imshow(img, vmin=0, vmax=3)
    plt.gca().add_patch(plt.Rectangle((360, 5), 60, 60, fill=False, edgecolor='red', linewidth=2))    
    plt.axis('off')

    plt.savefig(img_dir + '/image{}_box.png'.format(i), bbox_inches='tight',pad_inches = 0)



for i in range(1, 9):
    img = plt.imread(img_dir + '/image{}.png'.format(i))
    draw_box(img)
